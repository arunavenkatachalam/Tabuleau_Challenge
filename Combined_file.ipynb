# %%
import pandas as pd

# %%
pwd
# Out:
# 'D:\\Aruna Workspace\\BootCamp_DataAnalytics\\ClassRoomChallenge_Projects\\Challenges\\Module18_challenge\\Resources'

# %%
files_combine = ['Citi Bike_2023\JC-202301-citibike-tripdata.csv','Citi Bike_2023\JC-202302-citibike-tripdata.csv','Citi Bike_2023\JC-202303-citibike-tripdata.csv','Citi Bike_2023\JC-202304-citibike-tripdata.csv','Citi Bike_2023\JC-202305-citibike-tripdata.csv','Citi Bike_2023\JC-202306-citibike-tripdata.csv','Citi Bike_2023\JC-202307-citibike-tripdata.csv','Citi Bike_2023\JC-202308-citibike-tripdata.csv','Citi Bike_2023\JC-202309-citibike-tripdata.csv','Citi Bike_2023\JC-202310-citibike-tripdata.csv','Citi Bike_2023\JC-202311-citibike-tripdata.csv']
Comb_files = []

for file in files_combine:
    citi_file = pd.read_csv(file)
    Comb_files.append(citi_file)
    
citi_file = pd.concat(Comb_files)

citi_file
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      0905B18B365C9D20   classic_bike  2023-01-28 09:18:10
# 1      B4F0562B05CB5404  electric_bike  2023-01-23 20:10:12
# 2      5ABF032895F5D87E   classic_bike  2023-01-29 15:27:04
# 3      E7E1F9C53976D2F9   classic_bike  2023-01-24 18:35:08
# 4      323165780CA0734B   classic_bike  2023-01-21 20:44:09
# ...                 ...            ...                  ...
# 75641  EE6CF90DF3984253   classic_bike  2023-11-22 16:20:23
# 75642  DB574978E7FABC08   classic_bike  2023-11-21 07:01:57
# 75643  E8E26D6A35E922FA   classic_bike  2023-11-14 07:51:51
# 75644  0D6ECB6E18E32C63   classic_bike  2023-11-17 08:15:06
# 75645  817DBC6302EDF681   classic_bike  2023-11-16 10:55:31
#
#                   ended_at                        start_station_name  \
# 0      2023-01-28 09:28:52  Hoboken Terminal - Hudson St & Hudson Pl
# 1      2023-01-23 20:18:27  Hoboken Terminal - Hudson St & Hudson Pl
# ...

# %%
citi_file.to_csv('Citi Bike_2023\Combined_Data-citibike_2023.csv',index = False)
